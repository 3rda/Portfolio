# %% [markdown]
# ### Import Relevant Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set()
pd.options.display.max_columns = 10
pd.set_option('display.max_rows',10)

# %% [markdown]
# ### Import the data

# %% [markdown]
# ### Data from fbref.com

# %%
defensiveAction = pd.read_csv("DefensiveAction.csv")
shooting = pd.read_csv("Shooting.csv")
gca = pd.read_csv("GCA.csv")
passing = pd.read_csv("Passing.csv")
goalkeeper = pd.read_csv("gk.csv")
advGoalkeeper = pd.read_csv("AdvancedGk.csv")
msc = pd.read_csv("Msc.csv")

# %% [markdown]
# ### Dropping Unnecessary Columns

# %%
defensiveAction = defensiveAction.drop(['Matches', '-9999','Rk'],axis=1)
shooting = shooting.drop(['Matches', '-9999','Rk'],axis=1)
gca = gca.drop(['Matches', '-9999','Rk'],axis=1)
passing = passing.drop(['Matches', '-9999','Rk'],axis=1)
goalkeeper = goalkeeper.drop(['Matches', '-9999','Rk'],axis=1)
advGoalkeeper = advGoalkeeper.drop(['Matches', '-9999','Rk'],axis=1)
msc = msc.drop(['Matches','-9999','CrdY', 'CrdR', '2CrdY', 'Fls', 'Fld', 'Off', 'Crs', 'Int', 'TklW',
       'PKwon', 'PKcon', 'OG','Rk'],axis=1)

# %% [markdown]
# ### Joining Goalkeeper Data

# %%
merged_data_gk = pd.merge(goalkeeper,advGoalkeeper,on=['Player','Nation','Pos','Squad','Comp','Age','Born','90s','GA','PKA'])

# %%
merged_data_gk = merged_data_gk.drop(['Nation', 'Squad','Comp','Pos'],axis=1)

# %% [markdown]
# ### Joining Position Player Data

# %%
merged_data_pos = pd.merge(defensiveAction,shooting,on=['Player','Nation','Pos','Squad','Comp','Age','Born','90s'])
merged_data_pos = pd.merge(merged_data_pos,gca,on=['Player','Nation','Pos','Squad','Comp','Age','Born','90s'])
merged_data_pos = pd.merge(merged_data_pos,passing,on=['Player','Nation','Pos','Squad','Comp','Age','Born','90s'])
merged_data_pos = pd.merge(merged_data_pos,msc,on=['Player','Nation','Pos','Squad','Comp','Age','Born','90s'])

# %%
merged_data_pos = merged_data_pos.drop(['Squad','Born','Nation'],axis=1)

# %%
merged_data_pos
# Out:
#                  Player   Pos                Comp   Age   90s  ...  Prog  \
# 0            Max Aarons    DF  eng Premier League  21.0  32.0  ...    94
# 1      Yunis Abdelhamid    DF          fr Ligue 1  33.0  33.1  ...    90
# 2     Salis Abdul Samed    MF          fr Ligue 1  21.0  27.4  ...    81
# 3       Laurent Abergel    MF          fr Ligue 1  28.0  32.8  ...   137
# 4           Charles Abi    FW          fr Ligue 1  21.0   0.5  ...     0
# ...                 ...   ...                 ...   ...   ...  ...   ...
# 2911   Martín Zubimendi    MF          es La Liga  22.0  28.8  ...   106
# 2912   Szymon Żurkowski    MF          it Serie A  23.0  25.6  ...    68
# 2913    Martin Ødegaard    MF  eng Premier League  22.0  30.9  ...   158
# 2914        Milan Đurić    FW          it Serie A  31.0  24.1  ...    30
# 2915      Filip Đuričić  MFFW          it Serie A  29.0   7.5  ...    34
#
#       Recov  Won  Lost   Won%
# 0       177   15    51   22.7
# 1       224   67    45   59.8
# 2       240   24    24   50.0
# 3       291   14    14   50.0
# 4         2    1     0  100.0
# ...     ...  ...   ...    ...
# 2911    271   76    40   65.5
# 2912    206   26    40   39.4
# 2913    230   17    25   40.5
# 2914     78  298   116   72.0
# 2915     35    3     5   37.5
#
# [2916 rows x 87 columns]

# %% [markdown]
# ### Dropping non-qualified players

# %%
merged_data_pos_qualified = merged_data_pos[merged_data_pos['Pos']!= 'GK']
merged_data_pos_qualified = merged_data_pos_qualified[merged_data_pos_qualified['90s']>= 19]

# %%
merged_data_pos_qualified.isna().sum()
# Out:
# Player    0
# Pos       0
# Comp      0
# Age       0
# 90s       0
#          ..
# Prog      0
# Recov     0
# Won       0
# Lost      0
# Won%      0
# Length: 87, dtype: int64

# %% [markdown]
# Column that has null value
# - TKL%
# - G/SoT

# %%
merged_data_pos_qualified[merged_data_pos_qualified['G/SoT'].isna()]
# Out:
#                Player Pos                Comp   Age   90s  ...  Prog  Recov  \
# 74      Yeray Álvarez  DF          es La Liga  26.0  20.7  ...    61    253
# 108     Dennis Appiah  DF          fr Ligue 1  29.0  23.3  ...    75    166
# 384    Cédric Brunner  DF       de Bundesliga  27.0  24.3  ...    76    240
# 464    Andrea Carboni  DF          it Serie A  20.0  24.6  ...    81    223
# 476     Nicolò Casale  DF          it Serie A  23.0  28.7  ...    73    292
# ...               ...  ..                 ...   ...   ...  ...   ...    ...
# 2352    Mamadou Sakho  DF          fr Ligue 1  31.0  28.6  ...    91    267
# 2576  Stefano Sturaro  MF          it Serie A  28.0  19.6  ...    50    204
# 2614   Charlie Taylor  DF  eng Premier League  27.0  30.3  ...    79    275
# 2638      Luke Thomas  DF  eng Premier League  20.0  21.2  ...    73    192
# 2799       Kevin Vogt  DF       de Bundesliga  29.0  28.5  ...   137    341
#
#       Won  Lost  Won%
# 74     70    46  60.3
# 108    36    44  45.0
# 384    57    39  59.4
# 464    59    45  56.7
# 476    85    63  57.4
# ...   ...   ...   ...
# 2352   63    39  61.8
# 2576   54    59  47.8
# 2614   66    34  66.0
# 2638   30    39  43.5
# 2799   36    39  48.0
#
# [28 rows x 87 columns]

# %% [markdown]
# - Null TKL% and G/SoT data is not a missing value, that player really have 0 in TKL% (because they didn' attempt any tackle), or 0 in G/SoT (Didn't have any shot on target), so i'll fill it with 0

# %%
merged_data_pos_qualified['Tkl%'] = merged_data_pos_qualified['Tkl%'].fillna(value=0)
merged_data_pos_qualified['G/SoT'] = merged_data_pos_qualified['G/SoT'].fillna(value=0)

# %%
merged_data_pos_qualified[merged_data_pos_qualified['Tkl%'].isna()]
# Out:
# Empty DataFrame
# Columns: [Player, Pos, Comp, Age, 90s, Tkl, TklW, Def 3rd, Mid 3rd, Att 3rd, Tkl.1, Att_x, Tkl%, Past, Press, Succ, %, Def 3rd.1, Mid 3rd.1, Att 3rd.1, Blocks, Sh_x, ShSv, Pass, Int, Tkl+Int, Clr, Err, Gls, Sh_y, SoT, SoT%, Sh/90, SoT/90, G/Sh, G/SoT, Dist, FK, PK, PKatt, xG, npxG, npxG/Sh, G-xG, np:G-xG, SCA, SCA90, PassLive, PassDead, Drib, Sh, Fld, Def, GCA, GCA90, PassLive.1, PassDead.1, Drib.1, Sh.1, Fld.1, Def.1, Cmp, Att_y, Cmp%, TotDist, PrgDist, Cmp.1, Att.1, Cmp%.1, Cmp.2, Att.2, Cmp%.2, Cmp.3, Att.3, Cmp%.3, Ast, xA, A-xA, KP, 1/3, PPA, CrsPA, Prog, Recov, Won, Lost, Won%]
# Index: []
#
# [0 rows x 87 columns]

# %%
merged_data_pos_qualified[merged_data_pos_qualified['G/SoT'].isna()]
# Out:
# Empty DataFrame
# Columns: [Player, Pos, Comp, Age, 90s, Tkl, TklW, Def 3rd, Mid 3rd, Att 3rd, Tkl.1, Att_x, Tkl%, Past, Press, Succ, %, Def 3rd.1, Mid 3rd.1, Att 3rd.1, Blocks, Sh_x, ShSv, Pass, Int, Tkl+Int, Clr, Err, Gls, Sh_y, SoT, SoT%, Sh/90, SoT/90, G/Sh, G/SoT, Dist, FK, PK, PKatt, xG, npxG, npxG/Sh, G-xG, np:G-xG, SCA, SCA90, PassLive, PassDead, Drib, Sh, Fld, Def, GCA, GCA90, PassLive.1, PassDead.1, Drib.1, Sh.1, Fld.1, Def.1, Cmp, Att_y, Cmp%, TotDist, PrgDist, Cmp.1, Att.1, Cmp%.1, Cmp.2, Att.2, Cmp%.2, Cmp.3, Att.3, Cmp%.3, Ast, xA, A-xA, KP, 1/3, PPA, CrsPA, Prog, Recov, Won, Lost, Won%]
# Index: []
#
# [0 rows x 87 columns]

# %% [markdown]
# Column that has similar name, and it's meaning
# - Tkl -> Number of Players tackled
# - Tkl.1 -> Number of Dribblers Tackled
# - Tkl%.1 -> Number of tackles win divided by total tackle attempts
# - Def 3rd, Mid 3rd , Att 3rd -> Tackles
# - Def 3rd.1 , Mid 3rd.1, Att 3rd.1 -> Applying pressures
# - Sh_x -> shot blocked by standing in it's path
# - Sh_y -> shot total (not including penalty kicks)
# - Pass Live, Pass Dead -> Live ball and dead ball passes that lead to a shot attempt
# - Drib -> Succesful dribble that lead to shot attempt
# - Sh -> Shot that leads to another shot attempt
# - Fld -> Fouls drawn that lead to shot attempt
# - Def -> Defensive Action that lead to shot attempt
# - Pass Live.1 , Pass Dead.1 -> Live ball and dead ball passes that lead to a goal
# - Drib.1 -> Succesful dribble that lead to goal
# - Sh.1 -> Shot that leads to another goal
# - Fld.1 -> Fouls drawn that lead to goal
# - Def.1 -> Defensive Action that lead to goal
# - Att_x -> Number of dribbled passed plus number of tackles (Tkl.1 + Past)
# - Cmp,Att_y, Cmp% ->Total Passes Completed, Attempted, and Total Passes Completed Percentage
# - Cmp,Att,Cmp%.1 -> Short Passes Completed, Attempted, and Total Passes Completed Percentage (between 5 and 15 yards)
# - Cmp,Att,Cmp%.2 -> Medium Passes Completed, Attempted, and Total Passes Completed Percentage (between 15 and 30 yards)
# - Cmp,Att,Cmp%.3 -> Long Passes Completed, Attempted, and Total Passes Completed Percentage (longer than 30 yards)

# %%
merged_data_pos_qualified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 879 entries, 0 to 2914
# Data columns (total 87 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Player      879 non-null    object
#  1   Pos         879 non-null    object
#  2   Comp        879 non-null    object
#  3   Age         879 non-null    float64
#  4   90s         879 non-null    float64
#  5   Tkl         879 non-null    int64
#  6   TklW        879 non-null    int64
#  7   Def 3rd     879 non-null    int64
#  8   Mid 3rd     879 non-null    int64
#  9   Att 3rd     879 non-null    int64
#  10  Tkl.1       879 non-null    int64
#  11  Att_x       879 non-null    int64
#  12  Tkl%        879 non-null    float64
#  13  Past        879 non-null    int64
#  14  Press       879 non-null    int64
#  15  Succ        879 non-null    int64
#  16  %           879 non-null    float64
#  17  Def 3rd.1   879 non-null    int64
#  18  Mid 3rd.1   879 non-null    int64
#  19  Att 3rd.1   879 non-null    int64
#  20  Blocks      879 non-null    int64
#  21  Sh_x        879 non-null    int64
#  22  ShSv        879 non-null    int64
#  23  Pass        879 non-null    int64
#  24  Int         879 non-null    int64
#  25  Tkl+Int     879 non-null    int64
#  26  Clr         879 non-null    int64
#  27  Err         879 non-null    int64
#  28  Gls         879 non-null    int64
#  29  Sh_y        879 non-null    int64
#  30  SoT         879 non-null    int64
#  31  SoT%        879 non-null    float64
#  32  Sh/90       879 non-null    float64
#  33  SoT/90      879 non-null    float64
#  34  G/Sh        879 non-null    float64
#  35  G/SoT       879 non-null    float64
#  36  Dist        879 non-null    float64
#  37  FK          879 non-null    int64
#  38  PK          879 non-null    int64
#  39  PKatt       879 non-null    int64
#  40  xG          879 non-null    float64
#  41  npxG        879 non-null    float64
#  42  npxG/Sh     879 non-null    float64
#  43  G-xG        879 non-null    float64
#  44  np:G-xG     879 non-null    float64
#  45  SCA         879 non-null    int64
#  46  SCA90       879 non-null    float64
#  47  PassLive    879 non-null    int64
#  48  PassDead    879 non-null    int64
#  49  Drib        879 non-null    int64
#  50  Sh          879 non-null    int64
#  51  Fld         879 non-null    int64
#  52  Def         879 non-null    int64
#  53  GCA         879 non-null    int64
#  54  GCA90       879 non-null    float64
#  55  PassLive.1  879 non-null    int64
#  56  PassDead.1  879 non-null    int64
#  57  Drib.1      879 non-null    int64
#  58  Sh.1        879 non-null    int64
#  59  Fld.1       879 non-null    int64
#  60  Def.1       879 non-null    int64
#  61  Cmp         879 non-null    int64
#  62  Att_y       879 non-null    int64
#  63  Cmp%        879 non-null    float64
#  64  TotDist     879 non-null    int64
#  65  PrgDist     879 non-null    int64
#  66  Cmp.1       879 non-null    int64
#  67  Att.1       879 non-null    int64
#  68  Cmp%.1      879 non-null    float64
#  69  Cmp.2       879 non-null    int64
#  70  Att.2       879 non-null    int64
#  71  Cmp%.2      879 non-null    float64
#  72  Cmp.3       879 non-null    int64
#  73  Att.3       879 non-null    int64
#  74  Cmp%.3      879 non-null    float64
#  75  Ast         879 non-null    int64
#  76  xA          879 non-null    float64
#  77  A-xA        879 non-null    float64
#  78  KP          879 non-null    int64
#  79  1/3         879 non-null    int64
#  80  PPA         879 non-null    int64
#  81  CrsPA       879 non-null    int64
#  82  Prog        879 non-null    int64
#  83  Recov       879 non-null    int64
#  84  Won         879 non-null    int64
#  85  Lost        879 non-null    int64
#  86  Won%        879 non-null    float64
# dtypes: float64(24), int64(60), object(3)
# memory usage: 604.3+ KB

# %% [markdown]
# ### Column Groups

# %% [markdown]
# ### Defensive Action
# - Defense : Tackles,vs Dribbles, Tackle%, Pressures, Blocks
# - Vs Dribbles : Tkl.1, Att.x, Tkl%, Past
# - Pressures : Press, Succ, %, Def 3rd.1, Mid 3rd.1, Att 3rd.1
# - Blocks : Blocks, Sh_x, ShSv, Pass
# - Etc :  Int, Tkl+Int, Clr, Err
#
# ### Shooting
# - Standard :Gls, Sh_y, SoT, SoT%, Sh/90, SoT/90, G/Sh, G/SoT, Dist, Fk, Pk, PKatt
# - Expected : xG, npxG, npxG/Sh, G-xG, np:G-xG
#
# ### GCA (Goal Creation Action)
# - SCA (Shot Creating Action) : SCA, SCA90
# - SCA Types : PassLive, PassDead, Drib, Sh, Fld, Def
# - GCA : GCA, GCA90
# - GCA Types : PassLive.1, PassDead.1, Drib.1, Sh.1, Fld.1, Def.1
#
# ### Passing
# - Total : Cmp, Att_y, Cmp%, TotDist, PrgDist
# - Short : Cmp.1, Att.1, Cmp%.1
# - Medium : Cmp.2, Att.2, Cmp%.2
# - Long : Cmp.3, Att.3, Cmp%.3
# - Etc : Ast, xA, A-xA, KP, 1/3, PPA, CrsPA, Prog

# %%
merged_data_pos_qualified.describe()
# Out:
#               Age         90s         Tkl        TklW     Def 3rd  ...  \
# count  879.000000  879.000000  879.000000  879.000000  879.000000  ...
# mean    26.053470   26.293402   45.607509   27.895336   22.233220  ...
# std      3.868347    4.738237   21.203204   13.657225   13.718085  ...
# min     16.000000   19.000000    2.000000    2.000000    0.000000  ...
# 25%     23.000000   22.250000   30.500000   18.000000   11.000000  ...
# 50%     26.000000   25.800000   44.000000   26.000000   21.000000  ...
# 75%     29.000000   30.100000   59.000000   36.000000   31.000000  ...
# max     39.000000   38.000000  130.000000   80.000000   74.000000  ...
#
#              Prog       Recov         Won        Lost        Won%
# count  879.000000  879.000000  879.000000  879.000000  879.000000
# mean    86.643914  209.902162   45.713311   43.300341   48.341183
# std     43.001980   76.772506   35.275611   27.594417   14.562125
# min      9.000000   43.000000    1.000000    2.000000    6.100000
# 25%     55.500000  153.500000   19.500000   26.000000   38.200000
# 50%     79.000000  205.000000   36.000000   37.000000   48.800000
# 75%    109.000000  260.000000   63.000000   51.000000   59.600000
# max    278.000000  459.000000  314.000000  225.000000   81.800000
#
# [8 rows x 84 columns]

# %%
merged_data_pos_qualified['Tkl%.1'] = merged_data_pos_qualified['TklW']/merged_data_pos_qualified['Tkl']*100
merged_data_pos_qualified['Tkl%.1'] = merged_data_pos_qualified['Tkl%.1'].round(decimals=1)

# %%
merged_data_pos_qualified
# Out:
#                  Player Pos                Comp   Age   90s  ...  Recov  Won  \
# 0            Max Aarons  DF  eng Premier League  21.0  32.0  ...    177   15
# 1      Yunis Abdelhamid  DF          fr Ligue 1  33.0  33.1  ...    224   67
# 2     Salis Abdul Samed  MF          fr Ligue 1  21.0  27.4  ...    240   24
# 3       Laurent Abergel  MF          fr Ligue 1  28.0  32.8  ...    291   14
# 7         Tammy Abraham  FW          it Serie A  23.0  34.3  ...    126   82
# ...                 ...  ..                 ...   ...   ...  ...    ...  ...
# 2908         Kurt Zouma  DF  eng Premier League  26.0  23.1  ...    164   55
# 2911   Martín Zubimendi  MF          es La Liga  22.0  28.8  ...    271   76
# 2912   Szymon Żurkowski  MF          it Serie A  23.0  25.6  ...    206   26
# 2913    Martin Ødegaard  MF  eng Premier League  22.0  30.9  ...    230   17
# 2914        Milan Đurić  FW          it Serie A  31.0  24.1  ...     78  298
#
#       Lost  Won%  Tkl%.1
# 0       51  22.7    53.6
# 1       45  59.8    74.2
# 2       24  50.0    61.8
# 3       14  50.0    62.4
# 7       99  45.3    64.7
# ...    ...   ...     ...
# 2908    25  68.8    45.5
# 2911    40  65.5    52.5
# 2912    40  39.4    69.0
# 2913    25  40.5    58.1
# 2914   116  72.0    66.7
#
# [879 rows x 88 columns]

# %% [markdown]
# ### Renaming the Column, so it'll be easier to understand

# %%
merged_data_pos_qualified = merged_data_pos_qualified.rename(columns={'Player' : 'Name',
                                                                      'Comp' : 'League',
                                                                      'Tkl' : 'TklAtt',
                                                                      'TklW' : 'TklWon',
                                                                      'Tkl%.1' : 'Tkl_Percentage%',
                                                                      'Def 3rd' : 'Def 3rd (Tkl)',
                                                                      'Mid 3rd' : 'Mid 3rd (Tkl)',
                                                                      'Att 3rd' : 'Att 3rd (Tkl)',
                                                                      'Tkl.1' : 'TklvsDrib',
                                                                      'Att_x' : 'TklAttvsDrib',
                                                                      'Tkl%' : 'Tkl%vsDrib',
                                                                      'Def 3rd.1' : 'Def 3rd (Pres)',
                                                                      'Mid 3rd.1' : 'Mid 3rd (Pres)',
                                                                      'Att 3rd.1' : 'Att 3rd (Pres)',
                                                                      '%' : 'Pres%',
                                                                      'Sh_x' : 'ShotBlocked',
                                                                      'Sh_y' : 'ShotsTotal',
                                                                      'PassLive' : 'PassLive(SCA)',
                                                                      'PassDead' : 'PassDead(SCA)',
                                                                      'Drib' : 'Drib(SCA)',
                                                                      'Sh' : 'Sh(SCA)',
                                                                      'Fld' : 'Fld(SCA)',
                                                                      'Def' : 'Def(SCA)',
                                                                      'PassLive.1' : 'PassLive(GCA)',
                                                                      'PassDead.1' : 'PassDead(GCA)',
                                                                      'Drib.1' : 'Drib(GCA)',
                                                                      'Sh.1' : 'Sh(GCA)',
                                                                      'Fld.1' : 'Fld(GCA)',
                                                                      'Def.1' : 'Def(GCA)',
                                                                      'Cmp' : 'PassCmp',
                                                                      'Att_y' : 'PassAtt',
                                                                      'Cmp.1' : 'PassCmp(Short)',
                                                                      'Att.1' : 'PassAtt(Short)',
                                                                      'Cmp%.1' : 'Cmp%(Short)',
                                                                      'Cmp.2' : 'PassCmp(Medium)',
                                                                      'Att.2' : 'PassAtt(Medium)',
                                                                      'Cmp%.2' : 'Cmp%(Medium)',
                                                                      'Cmp.3' : 'PassCmp(Long)',
                                                                      'Att.3' : 'PassAtt(Long)',
                                                                      'Cmp%.3' : 'Cmp%(Long)',
                                                                      'Won' : 'HeadersWon',
                                                                      'Lost' : 'HeadersLost',
                                                                      'Won%' : 'HeadersWon%'})

# %% [markdown]
# ### Calculatin per 90 Stats, and Headers Att

# %%
merged_data_pos_qualified['TklWon/90'] = merged_data_pos_qualified['TklWon'] / merged_data_pos_qualified['90s']
merged_data_pos_qualified['TklWon/90'] = merged_data_pos_qualified['TklWon/90'].round(decimals=1)
merged_data_pos_qualified['Succ/90'] = merged_data_pos_qualified['Succ'] / merged_data_pos_qualified['90s']
merged_data_pos_qualified['Succ/90'] = merged_data_pos_qualified['Succ/90'].round(decimals=1)
merged_data_pos_qualified['Blocks/90'] = merged_data_pos_qualified['Blocks'] / merged_data_pos_qualified['90s']
merged_data_pos_qualified['Blocks/90'] = merged_data_pos_qualified['Blocks/90'].round(decimals=1)
merged_data_pos_qualified['Int/90'] = merged_data_pos_qualified['Int'] / merged_data_pos_qualified['90s']
merged_data_pos_qualified['Int/90'] = merged_data_pos_qualified['Int/90'].round(decimals=1)
merged_data_pos_qualified['PassCmp/90'] = merged_data_pos_qualified['PassCmp'] / merged_data_pos_qualified['90s']
merged_data_pos_qualified['PassCmp/90'] = merged_data_pos_qualified['PassCmp/90'].round(decimals=1)
merged_data_pos_qualified['HeadersWon/90'] = merged_data_pos_qualified['HeadersWon'] / merged_data_pos_qualified['90s']
merged_data_pos_qualified['HeadersWon/90'] = merged_data_pos_qualified['HeadersWon/90'].round(decimals=1)
merged_data_pos_qualified['HeadersAtt'] = merged_data_pos_qualified['HeadersWon'] + merged_data_pos_qualified['HeadersLost']

# %% [markdown]
# ### Rearranging Columns

# %%
cols = ['Name', 'Pos', 'League', 'Age', '90s', 'TklAtt', 'TklWon',
       'Tkl_Percentage%', 'TklWon/90', 'Def 3rd (Tkl)', 'Mid 3rd (Tkl)', 'Att 3rd (Tkl)',
       'TklvsDrib', 'TklAttvsDrib', 'Tkl%vsDrib', 'Past', 'Succ', 'Press',
       'Pres%', 'Succ/90', 'Def 3rd (Pres)', 'Mid 3rd (Pres)', 'Att 3rd (Pres)', 'Blocks','Blocks/90',
       'ShotBlocked', 'ShSv', 'Pass', 'Int', 'Int/90', 'Tkl+Int', 'Clr', 'Err', 'Gls',
       'ShotsTotal', 'SoT', 'SoT%', 'Sh/90', 'SoT/90', 'G/Sh', 'G/SoT', 'Dist',
       'FK', 'PK', 'PKatt', 'xG', 'npxG', 'npxG/Sh', 'G-xG', 'np:G-xG', 'SCA',
       'SCA90', 'PassLive(SCA)', 'PassDead(SCA)', 'Drib(SCA)', 'Sh(SCA)',
       'Fld(SCA)', 'Def(SCA)', 'GCA', 'GCA90', 'PassLive(GCA)',
       'PassDead(GCA)', 'Drib(GCA)', 'Sh(GCA)', 'Fld(GCA)', 'Def(GCA)',
       'PassCmp', 'PassAtt', 'Cmp%', 'PassCmp/90', 'TotDist', 'PrgDist', 'PassCmp(Short)',
       'PassAtt(Short)', 'Cmp%(Short)', 'PassCmp(Medium)', 'PassAtt(Medium)',
       'Cmp%(Medium)', 'PassCmp(Long)', 'PassAtt(Long)', 'Cmp%(Long)', 'Ast',
       'xA', 'A-xA', 'KP', '1/3', 'PPA', 'CrsPA', 'Prog', 'Recov',
       'HeadersWon', 'HeadersLost', 'HeadersAtt','HeadersWon/90', 'HeadersWon%']

# %%
merged_data_pos_qualified = merged_data_pos_qualified[cols]

# %%
merged_data_pos_qualified
# Out:
#                    Name Pos              League   Age   90s  ...  HeadersWon  \
# 0            Max Aarons  DF  eng Premier League  21.0  32.0  ...          15
# 1      Yunis Abdelhamid  DF          fr Ligue 1  33.0  33.1  ...          67
# 2     Salis Abdul Samed  MF          fr Ligue 1  21.0  27.4  ...          24
# 3       Laurent Abergel  MF          fr Ligue 1  28.0  32.8  ...          14
# 7         Tammy Abraham  FW          it Serie A  23.0  34.3  ...          82
# ...                 ...  ..                 ...   ...   ...  ...         ...
# 2908         Kurt Zouma  DF  eng Premier League  26.0  23.1  ...          55
# 2911   Martín Zubimendi  MF          es La Liga  22.0  28.8  ...          76
# 2912   Szymon Żurkowski  MF          it Serie A  23.0  25.6  ...          26
# 2913    Martin Ødegaard  MF  eng Premier League  22.0  30.9  ...          17
# 2914        Milan Đurić  FW          it Serie A  31.0  24.1  ...         298
#
#       HeadersLost  HeadersAtt  HeadersWon/90  HeadersWon%
# 0              51          66            0.5         22.7
# 1              45         112            2.0         59.8
# 2              24          48            0.9         50.0
# 3              14          28            0.4         50.0
# 7              99         181            2.4         45.3
# ...           ...         ...            ...          ...
# 2908           25          80            2.4         68.8
# 2911           40         116            2.6         65.5
# 2912           40          66            1.0         39.4
# 2913           25          42            0.6         40.5
# 2914          116         414           12.4         72.0
#
# [879 rows x 95 columns]

# %% [markdown]
# ### Changing League Name

# %%
merged_data_pos_qualified['League'] = merged_data_pos_qualified['League'].replace(['fr Ligue 1','eng Premier League',
                                                                                   'it Serie A','es La Liga','de Bundesliga'],
                                                                                 ['Ligue 1','Premier League','Serie A','La Liga','Bundesliga'])

# %%
merged_data_pos_qualified
# Out:
#                    Name Pos          League   Age   90s  ...  HeadersWon  \
# 0            Max Aarons  DF  Premier League  21.0  32.0  ...          15
# 1      Yunis Abdelhamid  DF         Ligue 1  33.0  33.1  ...          67
# 2     Salis Abdul Samed  MF         Ligue 1  21.0  27.4  ...          24
# 3       Laurent Abergel  MF         Ligue 1  28.0  32.8  ...          14
# 7         Tammy Abraham  FW         Serie A  23.0  34.3  ...          82
# ...                 ...  ..             ...   ...   ...  ...         ...
# 2908         Kurt Zouma  DF  Premier League  26.0  23.1  ...          55
# 2911   Martín Zubimendi  MF         La Liga  22.0  28.8  ...          76
# 2912   Szymon Żurkowski  MF         Serie A  23.0  25.6  ...          26
# 2913    Martin Ødegaard  MF  Premier League  22.0  30.9  ...          17
# 2914        Milan Đurić  FW         Serie A  31.0  24.1  ...         298
#
#       HeadersLost  HeadersAtt  HeadersWon/90  HeadersWon%
# 0              51          66            0.5         22.7
# 1              45         112            2.0         59.8
# 2              24          48            0.9         50.0
# 3              14          28            0.4         50.0
# 7              99         181            2.4         45.3
# ...           ...         ...            ...          ...
# 2908           25          80            2.4         68.8
# 2911           40         116            2.6         65.5
# 2912           40          66            1.0         39.4
# 2913           25          42            0.6         40.5
# 2914          116         414           12.4         72.0
#
# [879 rows x 95 columns]

# %% [markdown]
# ### Exporting the CSV

# %%
#merged_data_pos_qualified.to_csv('Position_Player.csv')
